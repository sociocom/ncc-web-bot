# %%
import pandas as pd

# %%
df = pd.read_csv(
    "../data/NCC_FAQ data_do not apply to ChatGPT - _old_original.csv"
)
df
# Out:
#           NCC_ID    NCC_ID(修正後)  ハイフン前  ハイフン後  \
# 0        NCC-1-3     NCC-0001-3      1    3.0
# 1        NCC-1-7     NCC-0001-7      1    7.0
# 2       NCC-1-11    NCC-0001-11      1   11.0
# 3     NCC-1-13-1  NCC-0001-13-1  44939    1.0
# 4     NCC-1-13-2  NCC-0001-13-2  44939    2.0
# ...          ...            ...    ...    ...
# 1009     3-18-1.            NaN    NaN    NaN
# 1010     3-18-2.            NaN    NaN    NaN
# 1011     3-20-1.            NaN    NaN    NaN
# 1012     3-20-2.            NaN    NaN    NaN
# 1013     3-20-3.         3-1-1.    NaN    NaN
#
#                                           NCC-LayTopics  \
# 0     乳がんと診断されまして、今週手術するんですけど、腫瘍の大きさが2cm弱くらいで、今年とかいろ...
# 1        手術前の診断ではステージ１とは言われたんですけど。進行はその乳がん的には早いほうなんですか。
# 2                    造影剤使うのと使わないのではだいぶ違うんでしょうね、見え方というか。
# 3     PET検査ってあるじゃないですか。あれは骨シンチとかよりも、割りとこうわかりやすいような検査...
# 4     PET検査ってあるじゃないですか。あれは骨シンチとかよりも、割りとこうわかりやすいような検査...
# ...                                                 ...
# 1009                                                NaN
# 1010                                                NaN
# 1011                                                NaN
# 1012                                                NaN
# 1013                                                NaN
#
#                                                Question  \
# 0     乳がんと診断され今週手術をします。腫瘍の大きさが2cm弱くらいで、一通りの検査が終わり、臓器...
# 1     手術前診断でステージ１と言われました。リンパの腫れやひざ裏の腫れや痛みがあるのは乳がんの進行...
# 2                     造影剤を使う検査と使わない検査で、見え方がだいぶ違うのでしょうか。
# 3              PET検査というのがありますが、あれは骨シンチよりもわかりやすい検査なのですか。
# 4                        一般的に乳がんの検査の中でPET検査も取り入れるものですか。
# ...                                                 ...
# 1009                ステージⅡ、Her2陰性、ホルモン陰性の標準治療について知りたいです。
# 1010             がんの治療中（手術・抗がん剤治療）のコロナワクチン接種について知りたいです。
# 1011                    がんの治療後経過観察中です。四肢や顔面にむくみがあり心配です。
# 1012                 腕のリンパ浮腫がよくなりません。相談できる専門窓口を教えてください。
# 1013  乳がん治療後しばらくたちますが、胸から脇の下にかけての痛みがどうも治まらず生活の支障をきたし...
#
#                                                  Answer  \
# 0           再発・転移のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 1          乳がんの治療の流れでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 2            CT検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 3           PET検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 4           PET検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# ...                                                 ...
# 1009  がん情報サービスの「乳がん」もしくは患者さんのための乳がん診療ガイドラインQ19をご参照ください。
# 1010              国立がん研究センターが提供しているがん情報サービスの情報をご参照ください。
# 1011  乳がん治療後の体重増加や手足や顔の浮腫みについては、程度にもよりますが担当医や病院の相談窓口...
# 1012  まずは、担当医や病院の相談窓口、がん相談支援センターに相談してみましょう。すでに相談されてい...
# 1013  乳がんの術後何年経っても慢性的な痛みに悩まれる方は少なくありません。「乳房切除後疼痛(とうつ...
#
#                                           URL1_がん情報サービス  \
# 0     https://ganjoho.jp/public/knowledge/basic/canc...
# 1                                                   NaN
# 2     https://ganjoho.jp/public/dia_tre/inspection/c...
# 3     https://ganjoho.jp/public/cancer/breast/diagno...
# 4     https://ganjoho.jp/public/dia_tre/inspection/p...
# ...                                                 ...
# 1009  https://ganjoho.jp/public/cancer/breast/index....
# 1010  https://ganjoho.jp/public/support/infection/co...
# 1011                                                NaN
# 1012  https://hospdb.ganjoho.jp/kyoten/kyotenlist?cf...
# 1013                                                NaN
#
#                                           URL2_がん情報サービス URL3_がん情報サービス  ...  \
# 0                                                   NaN           NaN  ...
# 1                                                   NaN           NaN  ...
# 2                                                   NaN           NaN  ...
# 3     https://ganjoho.jp/public/dia_tre/inspection/p...           NaN  ...
# 4                                                   NaN           NaN  ...
# ...                                                 ...           ...  ...
# 1009                                                NaN           NaN  ...
# 1010                                                NaN           NaN  ...
# 1011                                                NaN           NaN  ...
# 1012  https://ganjoho.jp/public/support/condition/ly...           NaN  ...
# 1013                                                NaN           NaN  ...
#
#      path3_がん情報サービス                                        URL4_ガイドライン  \
# 0               NaN  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 1               NaN  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 2               NaN                                                NaN
# 3               NaN  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 4               NaN                                                NaN
# ...             ...                                                ...
# 1009            NaN  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 1010            NaN                                                NaN
# 1011            NaN                                                NaN
# 1012            NaN                                                NaN
# 1013            NaN  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
#
#                                             URL5_ガイドライン URL6_ガイドライン  \
# 0     https://jbcs.xsrv.jp/guidline/p2019/guidline/g...         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 1009                                                NaN         NaN
# 1010                                                NaN         NaN
# 1011                                                NaN         NaN
# 1012                                                NaN         NaN
# 1013                                                NaN         NaN
#
#      path4_ガイドライン path5_ガイドライン path6_ガイドライン   @  \
# 0          ガイドライン       ガイドライン          NaN NaN
# 1          ガイドライン          NaN          NaN NaN
# 2             NaN          NaN          NaN NaN
# 3          ガイドライン          NaN          NaN NaN
# 4             NaN          NaN          NaN NaN
# ...           ...          ...          ...  ..
# 1009       ガイドライン          NaN          NaN NaN
# 1010          NaN          NaN          NaN NaN
# 1011          NaN          NaN          NaN NaN
# 1012          NaN          NaN          NaN NaN
# 1013       ガイドライン          NaN          NaN NaN
#
#                            Question丸山メモ+                  堀拔お返事
# 0             どれくらいまで短く要約して良いか？ 20230106  書いていただいたものが良いように思います。
# 1     元のデータの文脈から赤字部分を補足したほうが良いか？20230106            ★奈良先端の先生に確認
# 2                                    NaN                    NaN
# 3                                    NaN                    NaN
# 4                                    NaN                    NaN
# ...                                  ...                    ...
# 1009                                 NaN                    NaN
# 1010                                 NaN                    NaN
# 1011                                 NaN                    NaN
# 1012                                 NaN                    NaN
# 1013                                 NaN                    NaN
#
# [1014 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['NCC_ID', 'NCC_ID(修正後)', 'ハイフン前', 'ハイフン後', 'NCC-LayTopics', 'Question',
#        'Answer', 'URL1_がん情報サービス', 'URL2_がん情報サービス', 'URL3_がん情報サービス',
#        'path1_がん情報サービス', 'path2_がん情報サービス', 'path3_がん情報サービス', 'URL4_ガイドライン',
#        'URL5_ガイドライン', 'URL6_ガイドライン', 'path4_ガイドライン', 'path5_ガイドライン',
#        'path6_ガイドライン', '@', 'Question丸山メモ+', '堀拔お返事'],
#       dtype='object')

# %%
df[["Question", "Answer", "URL1_がん情報サービス", "URL2_がん情報サービス", "URL3_がん情報サービス", "URL4_ガイドライン", "URL5_ガイドライン", "URL6_ガイドライン"]]
# Out:
#                                                Question  \
# 0     乳がんと診断され今週手術をします。腫瘍の大きさが2cm弱くらいで、一通りの検査が終わり、臓器...
# 1     手術前診断でステージ１と言われました。リンパの腫れやひざ裏の腫れや痛みがあるのは乳がんの進行...
# 2                     造影剤を使う検査と使わない検査で、見え方がだいぶ違うのでしょうか。
# 3              PET検査というのがありますが、あれは骨シンチよりもわかりやすい検査なのですか。
# 4                        一般的に乳がんの検査の中でPET検査も取り入れるものですか。
# ...                                                 ...
# 1009                ステージⅡ、Her2陰性、ホルモン陰性の標準治療について知りたいです。
# 1010             がんの治療中（手術・抗がん剤治療）のコロナワクチン接種について知りたいです。
# 1011                    がんの治療後経過観察中です。四肢や顔面にむくみがあり心配です。
# 1012                 腕のリンパ浮腫がよくなりません。相談できる専門窓口を教えてください。
# 1013  乳がん治療後しばらくたちますが、胸から脇の下にかけての痛みがどうも治まらず生活の支障をきたし...
#
#                                                  Answer  \
# 0           再発・転移のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 1          乳がんの治療の流れでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 2            CT検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 3           PET検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 4           PET検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# ...                                                 ...
# 1009  がん情報サービスの「乳がん」もしくは患者さんのための乳がん診療ガイドラインQ19をご参照ください。
# 1010              国立がん研究センターが提供しているがん情報サービスの情報をご参照ください。
# 1011  乳がん治療後の体重増加や手足や顔の浮腫みについては、程度にもよりますが担当医や病院の相談窓口...
# 1012  まずは、担当医や病院の相談窓口、がん相談支援センターに相談してみましょう。すでに相談されてい...
# 1013  乳がんの術後何年経っても慢性的な痛みに悩まれる方は少なくありません。「乳房切除後疼痛(とうつ...
#
#                                           URL1_がん情報サービス  \
# 0     https://ganjoho.jp/public/knowledge/basic/canc...
# 1                                                   NaN
# 2     https://ganjoho.jp/public/dia_tre/inspection/c...
# 3     https://ganjoho.jp/public/cancer/breast/diagno...
# 4     https://ganjoho.jp/public/dia_tre/inspection/p...
# ...                                                 ...
# 1009  https://ganjoho.jp/public/cancer/breast/index....
# 1010  https://ganjoho.jp/public/support/infection/co...
# 1011                                                NaN
# 1012  https://hospdb.ganjoho.jp/kyoten/kyotenlist?cf...
# 1013                                                NaN
#
#                                           URL2_がん情報サービス URL3_がん情報サービス  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3     https://ganjoho.jp/public/dia_tre/inspection/p...           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 1009                                                NaN           NaN
# 1010                                                NaN           NaN
# 1011                                                NaN           NaN
# 1012  https://ganjoho.jp/public/support/condition/ly...           NaN
# 1013                                                NaN           NaN
#
#                                             URL4_ガイドライン  \
# 0     https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 1     https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 2                                                   NaN
# 3     https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 4                                                   NaN
# ...                                                 ...
# 1009  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 1010                                                NaN
# 1011                                                NaN
# 1012                                                NaN
# 1013  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
#
#                                             URL5_ガイドライン URL6_ガイドライン
# 0     https://jbcs.xsrv.jp/guidline/p2019/guidline/g...         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 1009                                                NaN         NaN
# 1010                                                NaN         NaN
# 1011                                                NaN         NaN
# 1012                                                NaN         NaN
# 1013                                                NaN         NaN
#
# [1014 rows x 8 columns]

# %%
"hello \tworld".split("\t")
# Out:
# ['hello ', 'world']

# %%
url = df["URL1_がん情報サービス"] 
pd.isnull(url[1])
# Out:
# True

# %%
df_a = df[["Question", "Answer", "URL1_がん情報サービス", "URL2_がん情報サービス", "URL3_がん情報サービス", "URL4_ガイドライン", "URL5_ガイドライン", "URL6_ガイドライン"]]

# %%
df_a["URL"] = df_a["URL1_がん情報サービス"].apply(lambda x: x if pd.notnull(x) else "")
# Out:
# /var/folders/6c/gc01yk9d27n18201xrtlqwhr0000gn/T/ipykernel_85343/163246200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a["URL"] = df_a["URL1_がん情報サービス"].apply(lambda x: x if pd.notnull(x) else "")

# %%
for col in df_a.columns[3:]:
    df_a["URL"] = df_a.apply(lambda x: x["URL"] + "\t" + x[col] if pd.notnull(x[col]) else x["URL"], axis=1)
# Out:
# /var/folders/6c/gc01yk9d27n18201xrtlqwhr0000gn/T/ipykernel_85343/144734192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a["URL"] = df_a.apply(lambda x: x["URL"] + "\t" + x[col] if pd.notnull(x[col]) else x["URL"], axis=1)

# %%
df_a["URL"].iloc[3].split("\t")
# Out:
# ['https://ganjoho.jp/public/cancer/breast/diagnosis.html',
#  'https://ganjoho.jp/public/dia_tre/inspection/pet.html',
#  'https://jbcs.xsrv.jp/guidline/p2019/guidline/g6/q44/',
#  'https://ganjoho.jp/public/cancer/breast/diagnosis.html',
#  'https://ganjoho.jp/public/dia_tre/inspection/pet.html',
#  'https://jbcs.xsrv.jp/guidline/p2019/guidline/g6/q44/']

# %%
df_a["URL"] = df_a["URL"].str.lstrip("\t")
# Out:
# /var/folders/6c/gc01yk9d27n18201xrtlqwhr0000gn/T/ipykernel_85343/87903718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a["URL"] = df_a["URL"].str.lstrip("\t")

# %%
df_a[["Question", "Answer", "URL"]]
# Out:
#                                                Question  \
# 0     乳がんと診断され今週手術をします。腫瘍の大きさが2cm弱くらいで、一通りの検査が終わり、臓器...
# 1     手術前診断でステージ１と言われました。リンパの腫れやひざ裏の腫れや痛みがあるのは乳がんの進行...
# 2                     造影剤を使う検査と使わない検査で、見え方がだいぶ違うのでしょうか。
# 3              PET検査というのがありますが、あれは骨シンチよりもわかりやすい検査なのですか。
# 4                        一般的に乳がんの検査の中でPET検査も取り入れるものですか。
# ...                                                 ...
# 1009                ステージⅡ、Her2陰性、ホルモン陰性の標準治療について知りたいです。
# 1010             がんの治療中（手術・抗がん剤治療）のコロナワクチン接種について知りたいです。
# 1011                    がんの治療後経過観察中です。四肢や顔面にむくみがあり心配です。
# 1012                 腕のリンパ浮腫がよくなりません。相談できる専門窓口を教えてください。
# 1013  乳がん治療後しばらくたちますが、胸から脇の下にかけての痛みがどうも治まらず生活の支障をきたし...
#
#                                                  Answer  \
# 0           再発・転移のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 1          乳がんの治療の流れでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 2            CT検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 3           PET検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# 4           PET検査のことでしたら、こちらの情報をご確認ください。ご参考になりましたら幸いです。
# ...                                                 ...
# 1009  がん情報サービスの「乳がん」もしくは患者さんのための乳がん診療ガイドラインQ19をご参照ください。
# 1010              国立がん研究センターが提供しているがん情報サービスの情報をご参照ください。
# 1011  乳がん治療後の体重増加や手足や顔の浮腫みについては、程度にもよりますが担当医や病院の相談窓口...
# 1012  まずは、担当医や病院の相談窓口、がん相談支援センターに相談してみましょう。すでに相談されてい...
# 1013  乳がんの術後何年経っても慢性的な痛みに悩まれる方は少なくありません。「乳房切除後疼痛(とうつ...
#
#                                                     URL
# 0     https://ganjoho.jp/public/knowledge/basic/canc...
# 1     https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# 2     https://ganjoho.jp/public/dia_tre/inspection/c...
# 3     https://ganjoho.jp/public/cancer/breast/diagno...
# 4     https://ganjoho.jp/public/dia_tre/inspection/p...
# ...                                                 ...
# 1009  https://ganjoho.jp/public/cancer/breast/index....
# 1010  https://ganjoho.jp/public/support/infection/co...
# 1011
# 1012  https://hospdb.ganjoho.jp/kyoten/kyotenlist?cf...
# 1013  https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
#
# [1014 rows x 3 columns]

# %%
df_a.iloc[-1]
# Out:
# Question         乳がん治療後しばらくたちますが、胸から脇の下にかけての痛みがどうも治まらず生活の支障をきたし...
# Answer           乳がんの術後何年経っても慢性的な痛みに悩まれる方は少なくありません。「乳房切除後疼痛(とうつ...
# URL1_がん情報サービス                                                  NaN
# URL2_がん情報サービス                                                  NaN
# URL3_がん情報サービス                                                  NaN
# URL4_ガイドライン      https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# URL5_ガイドライン                                                    NaN
# URL6_ガイドライン                                                    NaN
# URL              https://jbcs.xsrv.jp/guidline/p2019/guidline/g...
# Name: 1013, dtype: object

# %%
df_a["URL"] = df_a["URL"].astype(str)
# Out:
# /var/folders/6c/gc01yk9d27n18201xrtlqwhr0000gn/T/ipykernel_85343/1479396380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a["URL"] = df_a["URL"].astype(str)

# %%
df_a["URL"] = df_a["URL"].str.replace("\t\t", "\t")
# Out:
# /var/folders/6c/gc01yk9d27n18201xrtlqwhr0000gn/T/ipykernel_85343/3756949839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a["URL"] = df_a["URL"].str.replace("\t\t", "\t")

# %%
l = df_a.iloc[-1]["URL"].split("\t")
l
# Out:
# ['https://jbcs.xsrv.jp/guidline/p2019/guidline/g6/q25/',
#  'https://jbcs.xsrv.jp/guidline/p2019/guidline/g6/q25/']

# %%
list(dict.fromkeys(l))
# Out:
# ['https://jbcs.xsrv.jp/guidline/p2019/guidline/g6/q25/']

# %%
df_a.loc[df_a["URL"] == "", "URL"] = None

# %%
df_a[["Question", "Answer", "URL"]].to_csv(
    "../data/qa_sheet.csv",
)
